# %%
import matplotlib.pyplot as plt

import config

# %load_ext autoreload
# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline
from FLUCCOplus.notebooks import *
import pandas as pd
# Out:
# FLUCCOplus.notebooks loaded!
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_excel(config.DATA_INTERIM / "BauZ.xlsx", sheet_name="python")
# df = df[df.Huelle == "PH"]
# df = df[df.Bauweise == "Massiv"]
df = df.drop(46)
df
# Out:
#    Huelle Bauweise  dT        Freigabe    PEBedarf  PEExport     PESaldo  \
# 0     OIB   Leicht  0K    Wind2020>50% -155.702579       0.0 -155.702579
# 1     OIB   Mittel  0K    Wind2020>50% -154.782896       0.0 -154.782896
# 2     OIB   Massiv  0K    Wind2020>50% -154.293008       0.0 -154.293008
# 3      PH   Leicht  0K    Wind2020>50% -118.441829       0.0 -118.441829
# 4      PH   Mittel  0K    Wind2020>50% -117.773524       0.0 -117.773524
# 5      PH   Massiv  0K    Wind2020>50% -117.337790       0.0 -117.337790
# 6     OIB   Leicht  1K    Wind2020>50% -154.054996       0.0 -154.054996
# 7     OIB   Mittel  1K    Wind2020>50% -153.093155       0.0 -153.093155
# 8     OIB   Massiv  1K    Wind2020>50% -152.657757       0.0 -152.657757
# 9      PH   Leicht  1K    Wind2020>50% -117.200789       0.0 -117.200789
# 10     PH   Mittel  1K    Wind2020>50% -116.470470       0.0 -116.470470
# 11     PH   Massiv  1K    Wind2020>50% -115.984955       0.0 -115.984955
# ...

# %%
import seaborn as sns
# y = "Netzdienlichkeit Nutzung"
y = "PEQ Alpha Bilanz"
fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line",col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_PEQ_Alpha.png")

# %%
y = "Verhältnis ND/Bedarf HEIZEN/KÜHLEN"
fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line",col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_ND_Bedarf_HeizKuehl.png")

# %%
y = "Verhältnis ND/Netz(ges) GESAMT"

fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line", col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_ND_Netz_ges.png")

# %%
y = "Verhältnis ND/Netz(ges) HEIZEN"

fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line", col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_ND_Netz_gesHeizen.png")

# %%
y = "Verhältnis ND/Netz(ges) KÜHLEN"

fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line", col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_ND_Netz_Kuehlen.png")

# %%
y = "Verhältnis ND/Netz(ges) HEIZEN/KÜHLEN"

fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line", col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_ND_Netz_heizkuel.png")

# %%
y = "Mittlere Raumtemperatur Heizsaison"
fig = sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line",col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_temp_heizen.png")

# %%
y = "Mittlere Raumtemperatur Kühlsaison"

sns.relplot(data=df, y = y, x="dT", hue="Freigabe", kind="line", col="Bauweise", row="Huelle")
plt.savefig(config.PLOTS / "BauZ_temp_kuehlen.png")
