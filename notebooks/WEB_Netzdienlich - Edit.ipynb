# %%
import pandas as pd
years = range(2011, 2021)
# year1 = 2012
list(years)
len(years)
# Out:
# 10

# %%
# Es wird hier die externe WEB-Datei eingelesen

# %%
df_web = pd.read_csv("../data/processed/WEB_normalized.csv", delimiter=";", parse_dates=True, index_col=0)
df_web
# Out:
#                      Neuhof I  Neuhof III  Maustrenk  STERN I  STERN II  \
# Datetime UCT
# 2011-01-01 00:00:00       0.0         0.0   0.228857      0.0       0.0
# 2011-01-01 01:00:00       0.0         0.0   0.291000      0.0       0.0
# 2011-01-01 02:00:00       0.0         0.0   0.242143      0.0       0.0
# 2011-01-01 03:00:00       0.0         0.0   0.224786      0.0       0.0
# 2011-01-01 04:00:00       0.0         0.0   0.333857      0.0       0.0
# ...                       ...         ...        ...      ...       ...
# 2020-12-02 19:00:00       0.0         0.0   0.569143      0.0       0.0
# 2020-12-02 20:00:00       0.0         0.0   0.670714      0.0       0.0
# 2020-12-02 21:00:00       0.0         0.0   0.842786      0.0       0.0
# 2020-12-02 22:00:00       0.0         0.0   0.583500      0.0       0.0
# 2020-12-02 23:00:00       0.0         0.0   0.414214      0.0       0.0
#
#                      STERN III
# Datetime UCT
# 2011-01-01 00:00:00        0.0
# ...

# %%
#df_web['Month'] = df_web.index.month
#df_web['Day'] = df_web.index.day
#df_web['time'] = df_web.index.time
#df_web['DateTime'] = df_web['Month'].astype(str).str.zfill(2) + '-' + df_web['Day'].astype(str).str.zfill(2) + '-' + df_web['time'].astype(str).str.zfill(2)
#df_web

# %%
# DataFrame wird nur für das ausgewählte Jahr definiert

# %%
df11 = df_web[df_web.index.year==years[0]]
df11 = df11.iloc[0:8760]
df12 = df_web[df_web.index.year==years[1]]
df12 = df12.iloc[0:8760]
df13 = df_web[df_web.index.year==years[2]]
df13 = df13.iloc[0:8760]
df14 = df_web[df_web.index.year==years[3]]
df14 = df14.iloc[0:8760]
df15 = df_web[df_web.index.year==years[4]]
df15 = df15.iloc[0:8760]
df16 = df_web[df_web.index.year==years[5]]
df16 = df16.iloc[0:8760]
df17 = df_web[df_web.index.year==years[6]]
df17 = df17.iloc[0:8760]
df18 = df_web[df_web.index.year==years[7]]
df18 = df18.iloc[0:8760]
df19 = df_web[df_web.index.year==years[8]]
df19 = df19.iloc[0:8760]
df20 = df_web[df_web.index.year==years[9]]
df20 = df20.iloc[0:8760]

# %%
#Nimmt die jährliche Werte getrennt in einem NP-Array, falls es um ein Schaltjahr geht, löscht den letzten Tag

# %%
import numpy as np
dates11 = np.arange("2011-01-01","2012-01-01 00:00", dtype="datetime64[h]")
dates12 = np.arange("2012-01-01","2013-01-01 00:00", dtype="datetime64[h]")
dates13 = np.arange("2013-01-01","2014-01-01 00:00", dtype="datetime64[h]")
dates14 = np.arange("2014-01-01","2015-01-01 00:00", dtype="datetime64[h]")
dates15 = np.arange("2015-01-01","2016-01-01 00:00", dtype="datetime64[h]")
dates16 = np.arange("2016-01-01","2017-01-01 00:00", dtype="datetime64[h]")
dates17 = np.arange("2017-01-01","2018-01-01 00:00", dtype="datetime64[h]")
dates18 = np.arange("2018-01-01","2019-01-01 00:00", dtype="datetime64[h]")
dates19 = np.arange("2019-01-01","2020-01-01 00:00", dtype="datetime64[h]")
dates20 = np.arange("2020-01-01","2021-01-01 00:00", dtype="datetime64[h]")

if len(dates11) > 8760:
    dates11 = np.delete(dates11, range(8760,8784), axis=0)
if len(dates12) > 8760:
    dates12 = np.delete(dates12, range(8760,8784), axis=0)
if len(dates13) > 8760:
    dates13 = np.delete(dates13, range(8760,8784), axis=0)
if len(dates14) > 8760:
    dates14 = np.delete(dates14, range(8760,8784), axis=0)
if len(dates15) > 8760:
    dates15 = np.delete(dates15, range(8760,8784), axis=0)
if len(dates16) > 8760:
    dates16 = np.delete(dates16, range(8760,8784), axis=0)
if len(dates17) > 8760:
    dates17 = np.delete(dates17, range(8760,8784), axis=0)
if len(dates18) > 8760:
    dates18 = np.delete(dates18, range(8760,8784), axis=0)
if len(dates19) > 8760:
    dates19 = np.delete(dates19, range(8760,8784), axis=0)
if len(dates20) > 8760:
    dates20 = np.delete(dates20, range(8760,8784), axis=0)

# %%
#Liest den normalized-Excelfile ein, und tauscht den Index für das Jahr von der Windkraftanlage

# %%
df11_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df12_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df13_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df14_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df15_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df16_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df17_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df18_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df19_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)
df20_pee = pd.read_csv("../data/processed/peexcel_normalized.csv", index_col=0)

df11_pee.index = dates11
df12_pee.index = dates12
df13_pee.index = dates13
df14_pee.index = dates14
df15_pee.index = dates15
df16_pee.index = dates16
df17_pee.index = dates17
df18_pee.index = dates18
df19_pee.index = dates19
df20_pee.index = dates20

# %%
df11 = pd.concat([df11, df11_pee[["WEB 2015 Umgebung Wien"]]], axis=1)
df12 = pd.concat([df12, df12_pee[["WEB 2015 Umgebung Wien"]]], axis=1)
df13 = pd.concat([df13, df13_pee[["WEB 2015 Umgebung Wien", "Wind 2013"]]], axis=1)
df14 = pd.concat([df14, df14_pee[["WEB 2015 Umgebung Wien"]]], axis=1)
df15 = pd.concat([df15, df15_pee[["WEB 2015 Umgebung Wien", "Wind 2015"]]], axis=1)
df16 = pd.concat([df16, df16_pee[["WEB 2015 Umgebung Wien", "Wind 2016"]]], axis=1)
df17 = pd.concat([df17, df17_pee[["WEB 2015 Umgebung Wien", "Wind AT 2017"]]], axis=1)
df18 = pd.concat([df18, df18_pee[["WEB 2015 Umgebung Wien", "Wind AT 2018"]]], axis=1)
df19 = pd.concat([df19, df19_pee[["WEB 2015 Umgebung Wien", "Wind AT 2019"]]], axis=1)
df20 = pd.concat([df20, df20_pee[["WEB 2015 Umgebung Wien", "Wind AT 2020"]]], axis=1)

# %%
df15
# Out:
#                      Neuhof I  Neuhof III  Maustrenk   STERN I  STERN II  \
# 2015-01-01 00:00:00  0.013958    0.015853   0.025500  0.000000  0.000000
# 2015-01-01 01:00:00  0.025208    0.023038   0.009214  0.000000  0.000000
# 2015-01-01 02:00:00  0.000208    0.001514   0.000429  0.000000  0.000000
# 2015-01-01 03:00:00  0.006667    0.000000   0.000000  0.000000  0.000000
# 2015-01-01 04:00:00  0.004792    0.000000   0.000000  0.000000  0.000000
# ...                       ...         ...        ...       ...       ...
# 2015-12-31 19:00:00  0.240417    0.498610   0.633429  0.317250  0.266375
# 2015-12-31 20:00:00  0.242500    0.479623   0.525214  0.304875  0.319688
# 2015-12-31 21:00:00  0.214375    0.338736   0.439500  0.139875  0.188187
# 2015-12-31 22:00:00  0.108958    0.165358   0.222000  0.214500  0.182250
# 2015-12-31 23:00:00  0.092292    0.088183   0.122571  0.075563  0.056438
#
#                      STERN III  WEB 2015 Umgebung Wien  Wind 2015
# ...

# %%
#df11.index = df11.DateTime
#df12.index = df12.DateTime
#df13.index = df13.DateTime
#df14.index = df14.DateTime
#df15.index = df15.DateTime
#df16.index = df16.DateTime
#df17.index = df17.DateTime
#df18.index = df18.DateTime
#df19.index = df19.DateTime
#df20.index = df20.DateTime
#df11

# %% [markdown]
# Freigabesignal wenn > x% der Nennleistung

# %%
import os

if not os.path.exists("Plots"):
        os.makedirs("Plots")

# %%
type(df11)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt

cutoffs = [0.3,0.4,0.5,0.6]
anzahl11 = pd.DataFrame()
anzahl12 = pd.DataFrame()
anzahl13 = pd.DataFrame()
anzahl14 = pd.DataFrame()
anzahl15 = pd.DataFrame()
anzahl16 = pd.DataFrame()
anzahl17 = pd.DataFrame()
anzahl18 = pd.DataFrame()
anzahl19 = pd.DataFrame()
anzahl20 = pd.DataFrame()

fig, ax = plt.subplots(9, len(cutoffs), sharey=True, sharex=True, figsize=(8,6))
#plt.rc('font', size=3.4)
#plt.rc('axes', linewidth=0.3)
#plt.rc('grid', linewidth=0.2)
plt.rc('ytick', labelsize=7)
xtickssize = 2
xtickswidth= 0.3
ytickssize = 3
ytickswidth= 0.2

for i, x in enumerate(cutoffs):
    sig11 = df11.where(df11>x)
    sig11.count().plot(kind="bar", ylabel="2011", ax=ax[0, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[0, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[0, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig12 = df12.where(df12>x)
    sig12.count().plot(kind="bar", ylabel="2012", ax=ax[1, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[1, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[1, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig13 = df13.where(df13>x)
    sig13.count().plot(kind="bar", ylabel="2013", ax=ax[2, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[2, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[2, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig14 = df14.where(df14>x)
    sig14.count().plot(kind="bar", ylabel="2014", ax=ax[3, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[3, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[3, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig15 = df15.where(df15>x)
    sig15.count().plot(kind="bar", ylabel="2015", ax=ax[4, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[4, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[4, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig16 = df16.where(df16>x)
    sig16.count().plot(kind="bar", ylabel="2016", ax=ax[5, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[5, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[5, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig17 = df17.where(df17>x)
    sig17.count().plot(kind="bar", ylabel="2017", ax=ax[6, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[6, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[6, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig18 = df18.where(df18>x)
    sig18.count().plot(kind="bar", ylabel="2018", ax=ax[7, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[7, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[7, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig19 = df19.where(df19>x)
    sig19.count().plot(kind="bar", ylabel="2019", ax=ax[8, i]).grid(axis='y', linewidth=.4)
    plt.setp(ax[8, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    plt.setp(ax[8, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    sig20 = df20.where(df20>x)
    #sig20.count().plot(kind="bar", ylabel="2020", ax=ax[9, i]).grid(axis='y', linewidth=.4)
    #plt.setp(ax[9, i].xaxis.get_ticklines(), 'markersize', xtickssize, 'markeredgewidth', xtickswidth)
    #plt.setp(ax[9, i].yaxis.get_ticklines(), 'markersize', ytickssize, 'markeredgewidth', ytickswidth)
    ax[1, i].yaxis.set_ticks(np.arange(0, 3001, 1000))
    anzahl11[x] = sig11.count()
    anzahl12[x] = sig12.count()
    anzahl13[x] = sig13.count()
    anzahl14[x] = sig14.count()
    anzahl15[x] = sig15.count()
    anzahl16[x] = sig16.count()
    anzahl17[x] = sig17.count()
    anzahl18[x] = sig18.count()
    anzahl19[x] = sig19.count()
    anzahl20[x] = sig20.count()
    ax[0, 0].title.set_text("30%")
    ax[0, 1].title.set_text("40%")
    ax[0, 2].title.set_text("50%")
    ax[0, 3].title.set_text("60%")

fig.savefig("Plots/Freigabe-threshold_WEB_all.png", dpi=300, bbox_inches="tight")

# %%
sig17
# Out:
#                      Neuhof I  Neuhof III  Maustrenk  STERN I  STERN II  \
# 2017-01-01 00:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-01-01 01:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-01-01 02:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-01-01 03:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-01-01 04:00:00       NaN         NaN        NaN      NaN       NaN
# ...                       ...         ...        ...      ...       ...
# 2017-12-31 19:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-12-31 20:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-12-31 21:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-12-31 22:00:00       NaN         NaN        NaN      NaN       NaN
# 2017-12-31 23:00:00       NaN         NaN     0.7875      NaN       NaN
#
#                      STERN III  WEB 2015 Umgebung Wien  Wind AT 2017
# ...

# %%
import seaborn as sns
#anzahl
#sns.relplot(data=anzahl11)
#sns.relplot(data=anzahl12)
#sns.relplot(data=anzahl13)
#sns.relplot(data=anzahl14)
#sns.relplot(data=anzahl15)
#sns.relplot(data=anzahl16)
#sns.relplot(data=anzahl17)
#sns.relplot(data=anzahl18)
#sns.relplot(data=anzahl19)
#sns.relplot(data=anzahl20)

# %%
df11.fillna(0, inplace=True)
df12.fillna(0, inplace=True)
df13.fillna(0, inplace=True)
df14.fillna(0, inplace=True)
df15.fillna(0, inplace=True)
df16.fillna(0, inplace=True)
df17.fillna(0, inplace=True)
df18.fillna(0, inplace=True)
df19.fillna(0, inplace=True)
df20.fillna(0, inplace=True)

# %%
cut = 0.4
df11_sign = pd.DataFrame()
df12_sign = pd.DataFrame()
df13_sign = pd.DataFrame()
df14_sign = pd.DataFrame()
df15_sign = pd.DataFrame()
df16_sign = pd.DataFrame()
df17_sign = pd.DataFrame()
df18_sign = pd.DataFrame()
df19_sign = pd.DataFrame()
df20_sign = pd.DataFrame()

# %%
for c in df11.columns:
    df11_sign[c] = df11[c].map(lambda x: -1 if x < cut else 1)
for c in df12.columns:
    df12_sign[c] = df12[c].map(lambda x: -1 if x < cut else 1)
for c in df13.columns:
    df13_sign[c] = df13[c].map(lambda x: -1 if x < cut else 1)
for c in df14.columns:
    df14_sign[c] = df14[c].map(lambda x: -1 if x < cut else 1)
for c in df15.columns:
    df15_sign[c] = df15[c].map(lambda x: -1 if x < cut else 1)
for c in df16.columns:
    df16_sign[c] = df16[c].map(lambda x: -1 if x < cut else 1)
for c in df17.columns:
    df17_sign[c] = df17[c].map(lambda x: -1 if x < cut else 1)
for c in df18.columns:
    df18_sign[c] = df18[c].map(lambda x: -1 if x < cut else 1)
for c in df19.columns:
    df19_sign[c] = df19[c].map(lambda x: -1 if x < cut else 1)
for c in df20.columns:
    df20_sign[c] = df20[c].map(lambda x: -1 if x < cut else 1)

# %%
df11_S = df11.loc[(df11_sign.index.month >= 4) & (df11_sign.index.month < 10)]
df11_W = df11.loc[(df11_sign.index.month <4) | (df11_sign.index.month >= 10)]
df12_S = df12.loc[(df12_sign.index.month >= 4) & (df12_sign.index.month < 10)]
df12_W = df12.loc[(df12_sign.index.month <4) | (df12_sign.index.month >= 10)]
df13_S = df13.loc[(df13_sign.index.month >= 4) & (df13_sign.index.month < 10)]
df13_W = df13.loc[(df13_sign.index.month <4) | (df13_sign.index.month >= 10)]
df14_S = df14.loc[(df14_sign.index.month >= 4) & (df14_sign.index.month < 10)]
df14_W = df14.loc[(df14_sign.index.month <4) | (df14_sign.index.month >= 10)]
df15_S = df15.loc[(df15_sign.index.month >= 4) & (df15_sign.index.month < 10)]
df15_W = df15.loc[(df15_sign.index.month <4) | (df15_sign.index.month >= 10)]
df16_S = df16.loc[(df16_sign.index.month >= 4) & (df16_sign.index.month < 10)]
df16_W = df16.loc[(df16_sign.index.month <4) | (df16_sign.index.month >= 10)]
df17_S = df17.loc[(df17_sign.index.month >= 4) & (df17_sign.index.month < 10)]
df17_W = df17.loc[(df17_sign.index.month <4) | (df17_sign.index.month >= 10)]
df18_S = df18.loc[(df18_sign.index.month >= 4) & (df18_sign.index.month < 10)]
df18_W = df18.loc[(df18_sign.index.month <4) | (df18_sign.index.month >= 10)]
df19_S = df19.loc[(df19_sign.index.month >= 4) & (df19_sign.index.month < 10)]
df19_W = df19.loc[(df19_sign.index.month <4) | (df19_sign.index.month >= 10)]
df20_S = df20.loc[(df20_sign.index.month >= 4) & (df20_sign.index.month < 10)]
df20_W = df20.loc[(df20_sign.index.month <4) | (df20_sign.index.month >= 10)]

df11_S_sign = df11_sign.loc[(df11_sign.index.month >= 4) & (df11_sign.index.month < 10)]
df11_W_sign = df11_sign.loc[(df11_sign.index.month <4) | (df11_sign.index.month >= 10)]
df12_S_sign = df12_sign.loc[(df12_sign.index.month >= 4) & (df12_sign.index.month < 10)]
df12_W_sign = df12_sign.loc[(df12_sign.index.month <4) | (df12_sign.index.month >= 10)]
df13_S_sign = df13_sign.loc[(df13_sign.index.month >= 4) & (df13_sign.index.month < 10)]
df13_W_sign = df13_sign.loc[(df13_sign.index.month <4) | (df13_sign.index.month >= 10)]
df14_S_sign = df14_sign.loc[(df14_sign.index.month >= 4) & (df14_sign.index.month < 10)]
df14_W_sign = df14_sign.loc[(df14_sign.index.month <4) | (df14_sign.index.month >= 10)]
df15_S_sign = df15_sign.loc[(df15_sign.index.month >= 4) & (df15_sign.index.month < 10)]
df15_W_sign = df15_sign.loc[(df15_sign.index.month <4) | (df15_sign.index.month >= 10)]
df16_S_sign = df16_sign.loc[(df16_sign.index.month >= 4) & (df16_sign.index.month < 10)]
df16_W_sign = df16_sign.loc[(df16_sign.index.month <4) | (df16_sign.index.month >= 10)]
df17_S_sign = df17_sign.loc[(df17_sign.index.month >= 4) & (df17_sign.index.month < 10)]
df17_W_sign = df17_sign.loc[(df17_sign.index.month <4) | (df17_sign.index.month >= 10)]
df18_S_sign = df18_sign.loc[(df18_sign.index.month >= 4) & (df18_sign.index.month < 10)]
df18_W_sign = df18_sign.loc[(df18_sign.index.month <4) | (df18_sign.index.month >= 10)]
df19_S_sign = df19_sign.loc[(df19_sign.index.month >= 4) & (df19_sign.index.month < 10)]
df19_W_sign = df19_sign.loc[(df19_sign.index.month <4) | (df19_sign.index.month >= 10)]
df20_S_sign = df20_sign.loc[(df20_sign.index.month >= 4) & (df20_sign.index.month < 10)]
df20_W_sign = df20_sign.loc[(df20_sign.index.month <4) | (df20_sign.index.month >= 10)]

# %%
anzahl11_S = pd.DataFrame()
anzahl11_W = pd.DataFrame()
anzahl12_S = pd.DataFrame()
anzahl12_W = pd.DataFrame()
anzahl13_S = pd.DataFrame()
anzahl13_W = pd.DataFrame()
anzahl14_S = pd.DataFrame()
anzahl14_W = pd.DataFrame()
anzahl15_S = pd.DataFrame()
anzahl15_W = pd.DataFrame()
anzahl16_S = pd.DataFrame()
anzahl16_W = pd.DataFrame()
anzahl17_S = pd.DataFrame()
anzahl17_W = pd.DataFrame()
anzahl18_S = pd.DataFrame()
anzahl18_W = pd.DataFrame()
anzahl19_S = pd.DataFrame()
anzahl19_W = pd.DataFrame()
anzahl20_S = pd.DataFrame()
anzahl20_W = pd.DataFrame()
for i, x in enumerate(cutoffs):
    sig11_S = df11_S.where(df11_S>x)
    anzahl11_S[x] = sig11_S.count()
    sig11_W = df11_W.where(df11_W>x)
    anzahl11_W[x] = sig11_W.count()
    sig12_S = df12_S.where(df12_S>x)
    anzahl12_S[x] = sig12_S.count()
    sig12_W = df12_W.where(df12_W>x)
    anzahl12_W[x] = sig12_W.count()

    sig13_S = df13_S.where(df13_S>x)
    anzahl13_S[x] = sig13_S.count()
    sig13_W = df13_W.where(df13_W>x)
    anzahl13_W[x] = sig13_W.count()
    sig14_S = df14_S.where(df12_S>x)
    anzahl14_S[x] = sig14_S.count()
    sig14_W = df14_W.where(df14_W>x)
    anzahl14_W[x] = sig14_W.count()

    sig15_S = df15_S.where(df15_S>x)
    anzahl15_S[x] = sig15_S.count()
    sig15_W = df15_W.where(df15_W>x)
    anzahl15_W[x] = sig15_W.count()
    sig16_S = df16_S.where(df16_S>x)
    anzahl16_S[x] = sig16_S.count()
    sig16_W = df16_W.where(df16_W>x)
    anzahl16_W[x] = sig16_W.count()

    sig17_S = df17_S.where(df17_S>x)
    anzahl17_S[x] = sig17_S.count()
    sig17_W = df17_W.where(df17_W>x)
    anzahl17_W[x] = sig17_W.count()
    sig18_S = df18_S.where(df18_S>x)
    anzahl18_S[x] = sig18_S.count()
    sig18_W = df18_W.where(df18_W>x)
    anzahl18_W[x] = sig18_W.count()

    sig19_S = df19_S.where(df19_S>x)
    anzahl19_S[x] = sig19_S.count()
    sig19_W = df19_W.where(df19_W>x)
    anzahl19_W[x] = sig19_W.count()
    sig20_S = df20_S.where(df20_S>x)
    anzahl20_S[x] = sig20_S.count()
    sig20_W = df20_W.where(df20_W>x)
    anzahl20_W[x] = sig20_W.count()
anzahl18_W
# Out:
#                          0.3   0.4   0.5   0.6
# Neuhof I                1330   978   731   561
# Neuhof III              1576  1265  1027   826
# Maustrenk               1960  1633  1335  1100
# STERN I                 1169   936   764   604
# STERN II                1290  1022   810   609
# STERN III               1411  1120   906   745
# WEB 2015 Umgebung Wien  1280   963   720   529
# Wind AT 2018            1782  1302   877   577

# %%
max(anzahl18_S.max())
# Out:
# 1569

# %%
max(anzahl18_W.max())
# Out:
# 1960

# %%
max_score_18 = max(max(anzahl18_S.max()), max(anzahl18_W.max()))

# %%
ax_scale_18 = 0, (max_score_18 + 30)

fig, ax = plt.subplots(1, len(cutoffs), sharey=True)
for i, x in enumerate(cutoffs):
    sig18_S = df18_S.where(df18_S>x)
    sig18_S.count().plot(kind="bar", ax=ax[i], title=f"{x*100}%")
    anzahl18_S[x] = sig18_S.count()
    ax[i].set_ylim(ax_scale_18)
    ax[i].grid(axis='y')
    ax[i].set_ylabel("Stunden")
    for p in ax[i].patches:
      ax[i].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=7, color='black', xytext=(0, 5), textcoords='offset points')
fig.suptitle('April - Oktober (2018)', fontsize=14)
fig.savefig("Plots/Freigabe-threshold_Sommer_2018.png", dpi=300, bbox_inches="tight")

fig, ax = plt.subplots(1, len(cutoffs), sharey=True)
for i, x in enumerate(cutoffs):
    sig18_W = df18_W.where(df18_W>x)
    sig18_W.count().plot(kind="bar", ax=ax[i], title=f"{x*100}%")
    anzahl18_W[x] = sig18_W.count()
    ax[i].set_ylim(ax_scale_18)
    ax[i].grid(axis='y')
    ax[i].set_ylabel("Stunden")
    for p in ax[i].patches:
      ax[i].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=7, color='black', xytext=(0, 5), textcoords='offset points')
fig.suptitle('November - März (2018)', fontsize=14)
fig.savefig("Plots/Freigabe-threshold_Winter_2018.png", dpi=300, bbox_inches="tight")

# %%
anzahl18_S
# Out:
#                          0.3   0.4  0.5  0.6
# Neuhof I                1019   685  430  282
# Neuhof III              1346  1013  776  571
# Maustrenk               1569  1196  958  747
# STERN I                  895   661  485  332
# STERN II                1013   719  520  366
# STERN III                936   696  515  374
# WEB 2015 Umgebung Wien   897   621  426  283
# Wind AT 2018            1164   752  450  258

# %%
max_score_19 = max(max(anzahl19_S.max()), max(anzahl19_W.max()))
ax_scale_19 = 0, (max_score_19 + 30)

fig, ax = plt.subplots(1, len(cutoffs), sharey=True)
for i, x in enumerate(cutoffs):
    sig19_S = df19_S.where(df19_S>x)
    sig19_S.count().plot(kind="bar", ax=ax[i], title=f"{x*100}%")
    anzahl19_S[x] = sig19_S.count()
    ax[i].set_ylim(ax_scale_19)
    ax[i].grid(axis='y')
    ax[i].set_ylabel("Stunden")
    for p in ax[i].patches:
      ax[i].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=7, color='black', xytext=(0, 5), textcoords='offset points')
fig.suptitle('April - Oktober (2019)', fontsize=14)
fig.savefig("Plots/Freigabe-threshold_Sommer_2019.png", dpi=300, bbox_inches="tight")

fig, ax = plt.subplots(1, len(cutoffs), sharey=True)
for i, x in enumerate(cutoffs):
    sig19_W = df19_W.where(df19_W>x)
    sig19_W.count().plot(kind="bar", ax=ax[i], title=f"{x*100}%")
    anzahl19_W[x] = sig19_W.count()
    ax[i].set_ylim(ax_scale_19)
    ax[i].grid(axis='y')
    ax[i].set_ylabel("Stunden")
    for p in ax[i].patches:
      ax[i].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=7, color='black', xytext=(0, 5), textcoords='offset points')
fig.suptitle('November - März (2019)', fontsize=14)
fig.savefig("Plots/Freigabe-threshold_Winter_2019.png", dpi=300, bbox_inches="tight")

# %%
df18_S.where(df18_S>0.4).count()
# Out:
# Neuhof I                   685
# Neuhof III                1013
# Maustrenk                 1196
# STERN I                    661
# STERN II                   719
# STERN III                  696
# WEB 2015 Umgebung Wien     621
# Wind AT 2018               752
# dtype: int64

# %%
df11_S_step = pd.DataFrame()
df11_S_not = pd.DataFrame()
df11_W_step = pd.DataFrame()
df11_W_not = pd.DataFrame()
df12_S_step = pd.DataFrame()
df12_S_not = pd.DataFrame()
df12_W_step = pd.DataFrame()
df12_W_not = pd.DataFrame()
df13_S_step = pd.DataFrame()
df13_S_not = pd.DataFrame()
df13_W_step = pd.DataFrame()
df13_W_not = pd.DataFrame()
df14_S_step = pd.DataFrame()
df14_S_not = pd.DataFrame()
df14_W_step = pd.DataFrame()
df14_W_not = pd.DataFrame()
df15_S_step = pd.DataFrame()
df15_S_not = pd.DataFrame()
df15_W_step = pd.DataFrame()
df15_W_not = pd.DataFrame()
df16_S_step = pd.DataFrame()
df16_S_not = pd.DataFrame()
df16_W_step = pd.DataFrame()
df16_W_not = pd.DataFrame()
df17_S_not = pd.DataFrame()
df17_S_step = pd.DataFrame()
df17_W_not = pd.DataFrame()
df17_W_step = pd.DataFrame()
df18_S_not = pd.DataFrame()
df18_S_step = pd.DataFrame()
df18_W_not = pd.DataFrame()
df18_W_step = pd.DataFrame()
df19_S_step = pd.DataFrame()
df19_S_not = pd.DataFrame()
df19_W_step = pd.DataFrame()
df19_W_not = pd.DataFrame()
df20_S_step = pd.DataFrame()
df20_S_not = pd.DataFrame()
df20_W_step = pd.DataFrame()
df20_W_not = pd.DataFrame()

for c in df11_S_sign.columns:
    df11_S_step[c] =  df11_S_sign[c].shift(1).ne(df11_S_sign[c]).where(df11_S_sign[c]==1).cumsum()
    df11_S_not[c] =  df11_S_sign[c].shift(1).ne(df11_S_sign[c]).where(df11_S_sign[c]==-1).cumsum()
    df11_W_step[c] =  df11_W_sign[c].shift(1).ne(df11_W_sign[c]).where(df11_W_sign[c]==1).cumsum()
    df11_W_not[c] =  df11_W_sign[c].shift(1).ne(df11_W_sign[c]).where(df11_W_sign[c]==-1).cumsum()
for c in df12_S_sign.columns:
    df12_S_step[c] =  df12_S_sign[c].shift(1).ne(df12_S_sign[c]).where(df12_S_sign[c]==1).cumsum()
    df12_S_not[c] =  df12_S_sign[c].shift(1).ne(df12_S_sign[c]).where(df12_S_sign[c]==-1).cumsum()
    df12_W_step[c] =  df12_W_sign[c].shift(1).ne(df12_W_sign[c]).where(df12_W_sign[c]==1).cumsum()
    df12_W_not[c] =  df12_W_sign[c].shift(1).ne(df12_W_sign[c]).where(df12_W_sign[c]==-1).cumsum()
for c in df13_S_sign.columns:
    df13_S_step[c] =  df13_S_sign[c].shift(1).ne(df13_S_sign[c]).where(df13_S_sign[c]==1).cumsum()
    df13_S_not[c] =  df13_S_sign[c].shift(1).ne(df13_S_sign[c]).where(df13_S_sign[c]==-1).cumsum()
    df13_W_step[c] =  df13_W_sign[c].shift(1).ne(df13_W_sign[c]).where(df13_W_sign[c]==1).cumsum()
    df13_W_not[c] =  df13_W_sign[c].shift(1).ne(df13_W_sign[c]).where(df13_W_sign[c]==-1).cumsum()

for c in df14_S_sign.columns:
    df14_S_step[c] =  df14_S_sign[c].shift(1).ne(df14_S_sign[c]).where(df14_S_sign[c]==1).cumsum()
    df14_S_not[c] =  df14_S_sign[c].shift(1).ne(df14_S_sign[c]).where(df14_S_sign[c]==-1).cumsum()
    df14_W_step[c] =  df14_W_sign[c].shift(1).ne(df14_W_sign[c]).where(df14_W_sign[c]==1).cumsum()
    df14_W_not[c] =  df14_W_sign[c].shift(1).ne(df14_W_sign[c]).where(df14_W_sign[c]==-1).cumsum()
for c in df15_S_sign.columns:
    df15_S_step[c] =  df15_S_sign[c].shift(1).ne(df15_S_sign[c]).where(df15_S_sign[c]==1).cumsum()
    df15_S_not[c] =  df15_S_sign[c].shift(1).ne(df15_S_sign[c]).where(df15_S_sign[c]==-1).cumsum()
    df15_W_step[c] =  df15_W_sign[c].shift(1).ne(df15_W_sign[c]).where(df15_W_sign[c]==1).cumsum()
    df15_W_not[c] =  df15_W_sign[c].shift(1).ne(df15_W_sign[c]).where(df15_W_sign[c]==-1).cumsum()
for c in df16_S_sign.columns:
    df16_S_step[c] =  df16_S_sign[c].shift(1).ne(df16_S_sign[c]).where(df16_S_sign[c]==1).cumsum()
    df16_S_not[c] =  df16_S_sign[c].shift(1).ne(df16_S_sign[c]).where(df16_S_sign[c]==-1).cumsum()
    df16_W_step[c] =  df16_W_sign[c].shift(1).ne(df16_W_sign[c]).where(df16_W_sign[c]==1).cumsum()
    df16_W_not[c] =  df16_W_sign[c].shift(1).ne(df16_W_sign[c]).where(df16_W_sign[c]==-1).cumsum()

for c in df17_S_sign.columns:
    df17_S_step[c] =  df17_S_sign[c].shift(1).ne(df17_S_sign[c]).where(df17_S_sign[c]==1).cumsum()
    df17_S_not[c] =  df17_S_sign[c].shift(1).ne(df17_S_sign[c]).where(df17_S_sign[c]==-1).cumsum()
    df17_W_step[c] =  df17_W_sign[c].shift(1).ne(df17_W_sign[c]).where(df17_W_sign[c]==1).cumsum()
    df17_W_not[c] =  df17_W_sign[c].shift(1).ne(df17_W_sign[c]).where(df17_W_sign[c]==-1).cumsum()
for c in df18_S_sign.columns:
    df18_S_step[c] =  df18_S_sign[c].shift(1).ne(df18_S_sign[c]).where(df18_S_sign[c]==1).cumsum()
    df18_S_not[c] =  df18_S_sign[c].shift(1).ne(df18_S_sign[c]).where(df18_S_sign[c]==-1).cumsum()
    df18_W_step[c] =  df18_W_sign[c].shift(1).ne(df18_W_sign[c]).where(df18_W_sign[c]==1).cumsum()
    df18_W_not[c] =  df18_W_sign[c].shift(1).ne(df18_W_sign[c]).where(df18_W_sign[c]==-1).cumsum()
for c in df19_S_sign.columns:
    df19_S_step[c] =  df19_S_sign[c].shift(1).ne(df19_S_sign[c]).where(df19_S_sign[c]==1).cumsum()
    df19_S_not[c] =  df19_S_sign[c].shift(1).ne(df19_S_sign[c]).where(df19_S_sign[c]==-1).cumsum()
    df19_W_step[c] =  df19_W_sign[c].shift(1).ne(df19_W_sign[c]).where(df19_W_sign[c]==1).cumsum()
    df19_W_not[c] =  df19_W_sign[c].shift(1).ne(df19_W_sign[c]).where(df19_W_sign[c]==-1).cumsum()
for c in df20_S_sign.columns:
    df20_S_step[c] =  df20_S_sign[c].shift(1).ne(df20_S_sign[c]).where(df20_S_sign[c]==1).cumsum()
    df20_S_not[c] =  df20_S_sign[c].shift(1).ne(df20_S_sign[c]).where(df20_S_sign[c]==-1).cumsum()
    df20_W_step[c] =  df20_W_sign[c].shift(1).ne(df20_W_sign[c]).where(df20_W_sign[c]==1).cumsum()
    df20_W_not[c] =  df20_W_sign[c].shift(1).ne(df20_W_sign[c]).where(df20_W_sign[c]==-1).cumsum()

# %%
desc14_S = pd.DataFrame()
desc14_S["Zeitraum mit Signal [h]"] = anzahl14_S[cut]
desc14_S["Nicht-Signal-Zeitraum [h]"] = len(df14_S) - anzahl14_S[cut]
desc14_S["Anzahl Signal-Perioden"] = df14_S_step.max()
desc14_S["Durchschnittliche Dauer Signal [h]"] = (desc14_S["Zeitraum mit Signal [h]"]/desc14_S["Anzahl Signal-Perioden"])
desc14_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc14_S["Nicht-Signal-Zeitraum [h]"]/desc14_S["Anzahl Signal-Perioden"]

desc15_S = pd.DataFrame()
desc15_S["Zeitraum mit Signal [h]"] = anzahl15_S[cut]
desc15_S["Nicht-Signal-Zeitraum [h]"] = len(df15_S) - anzahl15_S[cut]
desc15_S["Anzahl Signal-Perioden"] = df15_S_step.max()
desc15_S["Durchschnittliche Dauer Signal [h]"] = (desc15_S["Zeitraum mit Signal [h]"]/desc15_S["Anzahl Signal-Perioden"])
desc15_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc15_S["Nicht-Signal-Zeitraum [h]"]/desc15_S["Anzahl Signal-Perioden"]

desc16_S = pd.DataFrame()
desc16_S["Zeitraum mit Signal [h]"] = anzahl16_S[cut]
desc16_S["Nicht-Signal-Zeitraum [h]"] = len(df16_S) - anzahl16_S[cut]
desc16_S["Anzahl Signal-Perioden"] = df16_S_step.max()
desc16_S["Durchschnittliche Dauer Signal [h]"] = (desc16_S["Zeitraum mit Signal [h]"]/desc16_S["Anzahl Signal-Perioden"])
desc16_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc16_S["Nicht-Signal-Zeitraum [h]"]/desc16_S["Anzahl Signal-Perioden"]

desc17_S = pd.DataFrame()
desc17_S["Zeitraum mit Signal [h]"] = anzahl17_S[cut]
desc17_S["Nicht-Signal-Zeitraum [h]"] = len(df17_S) - anzahl17_S[cut]
desc17_S["Anzahl Signal-Perioden"] = df17_S_step.max()
desc17_S["Durchschnittliche Dauer Signal [h]"] = (desc17_S["Zeitraum mit Signal [h]"]/desc17_S["Anzahl Signal-Perioden"])
desc17_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc17_S["Nicht-Signal-Zeitraum [h]"]/desc17_S["Anzahl Signal-Perioden"]

desc18_S = pd.DataFrame()
desc18_S["Zeitraum mit Signal [h]"] = anzahl18_S[cut]
desc18_S["Nicht-Signal-Zeitraum [h]"] = len(df18_S) - anzahl18_S[cut]
desc18_S["Anzahl Signal-Perioden"] = df18_S_step.max()
desc18_S["Durchschnittliche Dauer Signal [h]"] = (desc18_S["Zeitraum mit Signal [h]"]/desc18_S["Anzahl Signal-Perioden"])
desc18_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc18_S["Nicht-Signal-Zeitraum [h]"]/desc18_S["Anzahl Signal-Perioden"]

desc19_S = pd.DataFrame()
desc19_S["Zeitraum mit Signal [h]"] = anzahl19_S[cut]
desc19_S["Nicht-Signal-Zeitraum [h]"] = len(df19_S) - anzahl19_S[cut]
desc19_S["Anzahl Signal-Perioden"] = df19_S_step.max()
desc19_S["Durchschnittliche Dauer Signal [h]"] = (desc19_S["Zeitraum mit Signal [h]"]/desc19_S["Anzahl Signal-Perioden"])
desc19_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc19_S["Nicht-Signal-Zeitraum [h]"]/desc19_S["Anzahl Signal-Perioden"]

desc20_S = pd.DataFrame()
desc20_S["Zeitraum mit Signal [h]"] = anzahl20_S[cut]
desc20_S["Nicht-Signal-Zeitraum [h]"] = len(df20_S) - anzahl20_S[cut]
desc20_S["Anzahl Signal-Perioden"] = df20_S_step.max()
desc20_S["Durchschnittliche Dauer Signal [h]"] = (desc20_S["Zeitraum mit Signal [h]"]/desc20_S["Anzahl Signal-Perioden"])
desc20_S["Durchschnittliche Dauer Nicht-Signal [h]"] = desc20_S["Nicht-Signal-Zeitraum [h]"]/desc20_S["Anzahl Signal-Perioden"]

desc15_S
# Out:
#                         Zeitraum mit Signal [h]  Nicht-Signal-Zeitraum [h]  \
# Neuhof I                                    898                       3494
# Neuhof III                                 1260                       3132
# Maustrenk                                  1293                       3099
# STERN I                                     719                       3673
# STERN II                                    696                       3696
# STERN III                                     0                       4392
# WEB 2015 Umgebung Wien                      621                       3771
# Wind 2015                                   949                       3443
#
#                        Anzahl Signal-Perioden  \
# Neuhof I                                164.0
# Neuhof III                              208.0
# Maustrenk                               219.0
# STERN I                                 161.0
# STERN II                                167.0
# ...

# %%
desc14_W = pd.DataFrame()
desc14_W["Zeitraum mit Signal [h]"] = anzahl14_W[cut]
desc14_W["Nicht-Signal-Zeitraum [h]"] = len(df14_W) - anzahl14_W[cut]
desc14_W["Anzahl Signal-Perioden"] = df14_W_step.max()
desc14_W["Durchschnittliche Dauer Signal [h]"] = (desc14_W["Zeitraum mit Signal [h]"]/desc14_W["Anzahl Signal-Perioden"])
desc14_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc14_W["Nicht-Signal-Zeitraum [h]"]/desc14_W["Anzahl Signal-Perioden"]

desc15_W = pd.DataFrame()
desc15_W["Zeitraum mit Signal [h]"] = anzahl15_W[cut]
desc15_W["Nicht-Signal-Zeitraum [h]"] = len(df15_W) - anzahl15_W[cut]
desc15_W["Anzahl Signal-Perioden"] = df15_W_step.max()
desc15_W["Durchschnittliche Dauer Signal [h]"] = (desc15_W["Zeitraum mit Signal [h]"]/desc15_W["Anzahl Signal-Perioden"])
desc15_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc15_W["Nicht-Signal-Zeitraum [h]"]/desc15_W["Anzahl Signal-Perioden"]

desc16_W = pd.DataFrame()
desc16_W["Zeitraum mit Signal [h]"] = anzahl16_W[cut]
desc16_W["Nicht-Signal-Zeitraum [h]"] = len(df16_W) - anzahl16_W[cut]
desc16_W["Anzahl Signal-Perioden"] = df16_W_step.max()
desc16_W["Durchschnittliche Dauer Signal [h]"] = (desc16_W["Zeitraum mit Signal [h]"]/desc16_W["Anzahl Signal-Perioden"])
desc16_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc16_W["Nicht-Signal-Zeitraum [h]"]/desc16_W["Anzahl Signal-Perioden"]

desc17_W = pd.DataFrame()
desc17_W["Zeitraum mit Signal [h]"] = anzahl17_W[cut]
desc17_W["Nicht-Signal-Zeitraum [h]"] = len(df17_W) - anzahl17_W[cut]
desc17_W["Anzahl Signal-Perioden"] = df17_W_step.max()
desc17_W["Durchschnittliche Dauer Signal [h]"] = (desc17_W["Zeitraum mit Signal [h]"]/desc17_W["Anzahl Signal-Perioden"])
desc17_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc17_W["Nicht-Signal-Zeitraum [h]"]/desc17_W["Anzahl Signal-Perioden"]

desc18_W = pd.DataFrame()
desc18_W["Zeitraum mit Signal [h]"] = anzahl18_W[cut]
desc18_W["Nicht-Signal-Zeitraum [h]"] = len(df18_W) - anzahl18_W[cut]
desc18_W["Anzahl Signal-Perioden"] = df18_W_step.max()
desc18_W["Durchschnittliche Dauer Signal [h]"] = (desc18_W["Zeitraum mit Signal [h]"]/desc18_W["Anzahl Signal-Perioden"])
desc18_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc18_W["Nicht-Signal-Zeitraum [h]"]/desc18_W["Anzahl Signal-Perioden"]

desc19_W = pd.DataFrame()
desc19_W["Zeitraum mit Signal [h]"] = anzahl19_W[cut]
desc19_W["Nicht-Signal-Zeitraum [h]"] = len(df19_W) - anzahl19_W[cut]
desc19_W["Anzahl Signal-Perioden"] = df19_W_step.max()
desc19_W["Durchschnittliche Dauer Signal [h]"] = (desc19_W["Zeitraum mit Signal [h]"]/desc19_W["Anzahl Signal-Perioden"])
desc19_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc19_W["Nicht-Signal-Zeitraum [h]"]/desc19_W["Anzahl Signal-Perioden"]

desc20_W = pd.DataFrame()
desc20_W["Zeitraum mit Signal [h]"] = anzahl20_W[cut]
desc20_W["Nicht-Signal-Zeitraum [h]"] = len(df20_W) - anzahl20_W[cut]
desc20_W["Anzahl Signal-Perioden"] = df20_W_step.max()
desc20_W["Durchschnittliche Dauer Signal [h]"] = (desc20_W["Zeitraum mit Signal [h]"]/desc20_W["Anzahl Signal-Perioden"])
desc20_W["Durchschnittliche Dauer Nicht-Signal [h]"] = desc20_W["Nicht-Signal-Zeitraum [h]"]/desc20_W["Anzahl Signal-Perioden"]

desc15_W
# Out:
#                         Zeitraum mit Signal [h]  Nicht-Signal-Zeitraum [h]  \
# Neuhof I                                   1164                       3204
# Neuhof III                                 1460                       2908
# Maustrenk                                  1807                       2561
# STERN I                                    1042                       3326
# STERN II                                   1064                       3304
# STERN III                                     0                       4368
# WEB 2015 Umgebung Wien                      963                       3405
# Wind 2015                                  1207                       3161
#
#                        Anzahl Signal-Perioden  \
# Neuhof I                                159.0
# Neuhof III                              178.0
# Maustrenk                               191.0
# STERN I                                 149.0
# STERN II                                151.0
# ...

# %%
max_score_web = max(
    #max(desc14_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc15_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc16_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc17_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc18_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc19_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    #max(desc20_S["Durchschnittliche Dauer Nicht-Signal [h]"]),
    #max(desc14_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc15_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc16_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc17_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc18_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    max(desc19_W["Durchschnittliche Dauer Nicht-Signal [h]"]),
    #max(desc20_W["Durchschnittliche Dauer Nicht-Signal [h]"])
                  )

ax_scale_web = 0, (max_score_web + 2)

# %%
#text_size = 7
#plt.rc('font', size=text_size)          # controls default text sizes
#plt.rc('axes', titlesize=text_size-1)     # fontsize of the axes title
#plt.rc('axes', labelsize=text_size-1)

fig, ax = plt.subplots(5, 2, sharex=True, figsize=(12,6))


#desc14_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
#desc14_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 1])
desc15_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
desc15_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 1])
desc16_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[1, 0])
desc16_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[1, 1])
desc17_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[2, 0])
desc17_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[2, 1])
desc18_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[3, 0])
desc18_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[3, 1])
desc19_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[4, 0])
desc19_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[4, 1])
#desc20_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[7, 0])
#desc20_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[7, 1])
for i in range(5):
    for p in ax[i, 1].patches:
      ax[i, 1].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=6, color='black', xytext=(0, -3),
                     textcoords='offset points')
for i in range(5):
    for p in ax[i, 0].patches:
      ax[i, 0].annotate("{:.1f}%" .format(p.get_height()*100/len(df20_S)), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=6, color='blue', xytext=(0, -5),
                     textcoords='offset points')
for i in range(5):
    ax[i, 0].set_ylabel("Signalanteil \n {}" .format(years[i+4]))
    ax[i, 1].set_ylabel("Mittlere Signallänge \n {}" .format(years[i+4]))
    ax[i, 0].grid(axis='y', linewidth=0.3)
    ax[i, 1].grid(axis='y', linewidth=0.3)
    ax[i, 1].set_ylim(ax_scale_web)
fig.suptitle('April - Oktober (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/desc_WEB_sommer_{}.png" .format(cut), dpi=300)

# %%
fig, ax = plt.subplots(5, 2, sharex=True, figsize=(12,6))
#plt.rc('font', size=7)
#plt.rc('axes', linewidth=5.5)


#desc14_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
#desc14_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 1])
desc15_W[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
desc15_W[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 1])
desc16_W[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[1, 0])
desc16_W[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[1, 1])
desc17_W[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[2, 0])
desc17_W[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[2, 1])
desc18_W[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[3, 0])
desc18_W[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[3, 1])
desc19_W[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[4, 0])
desc19_W[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[4, 1])
#desc20_S[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[6, 0])
#desc20_S[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[6, 1])

plt.legend(loc=2)
for i in range(5):
    for p in ax[i, 1].patches:
      ax[i, 1].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=6, color='black', xytext=(0, -3),
                     textcoords='offset points')
for i in range(5):
    for p in ax[i, 0].patches:
      ax[i, 0].annotate("{:.1f}%" .format(p.get_height()*100/len(df20_W)), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=6, color='blue', xytext=(0, -5),
                     textcoords='offset points')
for i in range(5):
    ax[i, 0].set_ylabel("Stunden \n {}" .format(years[i+4]))
    ax[i, 1].set_ylabel("Stunden \n {}" .format(years[i+4]))
    ax[i, 0].grid(axis='y', linewidth=0.3)
    ax[i, 1].grid(axis='y', linewidth=0.3)
    ax[i, 1].set_ylim(ax_scale_web)
fig.suptitle('November - März (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/desc_WEB_winter_{}.png" .format(cut), dpi=300)

# %%
x = np.arange(8)

width = 0.2
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('axes', labelsize=9)
bar1 = plt.bar(x, len(sig18_S)-(df18_S.where(df18_S>0.3).count()), width, color="dimgrey", label="Nicht-Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, len(sig18_S)-(df18_S.where(df18_S>0.4).count()), width, color="grey", label="Nicht-Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, len(sig18_S)-(df18_S.where(df18_S>0.5).count()), width, color="darkgrey", label="Nicht-Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, len(sig18_S)-(df18_S.where(df18_S>0.6).count()), width, color="lightgrey", label="Nicht-Signal (cut by 60%)")
for summer in bar1 + bar2 + bar3 + bar4:
    height = summer.get_height()
    plt.text(summer.get_x() + summer.get_width() / 2.0, height-100, f'{height:.0f}', ha='center', va='top', fontsize=6.5, color='black')

bar1 = plt.bar(x, df18_S.where(df18_S>0.3).count(), width, color="#3b7fb9", label="Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, df18_S.where(df18_S>0.4).count(), width, color="#5593c8", label="Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, df18_S.where(df18_S>0.5).count(), width, color="#74a7d2", label="Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, df18_S.where(df18_S>0.6).count(), width, color="#92badc", label="Signal (cut by 60%)")
for summer in bar1 + bar2 + bar3 + bar4:
    height = summer.get_height()
    plt.text(summer.get_x() + summer.get_width() / 2.0, height+100, f'{height:.0f}', ha='center', va='bottom', fontsize=6.5, color='black')

plt.grid(axis="y", linewidth=0.3)
plt.xticks(x, sig18_S.columns)
plt.ylabel('Stunden')
plt.xticks(rotation=90)
plt.legend(loc="center right", fontsize=7.5, bbox_to_anchor=(1.25, 0.5))
plt.gcf().set_size_inches(10, 4)
plt.suptitle('April - Oktober (in 2018)', fontsize=14)
plt.savefig("Plots/web_freigabestunden_gruppiert_2018_summer.png", dpi=300, bbox_inches="tight")
plt.show()

plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('axes', labelsize=9)
bar1 = plt.bar(x, len(sig18_W)-(df18_W.where(df18_W>0.3).count()), width, color="dimgrey", label="Nicht-Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, len(sig18_W)-(df18_W.where(df18_W>0.4).count()), width, color="grey", label="Nicht-Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, len(sig18_W)-(df18_W.where(df18_W>0.5).count()), width, color="darkgrey", label="Nicht-Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, len(sig18_W)-(df18_W.where(df18_W>0.6).count()), width, color="lightgrey", label="Nicht-Signal (cut by 60%)")
for winter in bar1 + bar2 + bar3 + bar4:
    height = winter.get_height()
    plt.text(winter.get_x() + winter.get_width() / 2.0, height-100, f'{height:.0f}', ha='center', va='top', fontsize=6.5, color='black')

bar1 = plt.bar(x, df18_W.where(df18_W>0.3).count(), width, color="#3b7fb9", label="Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, df18_W.where(df18_W>0.4).count(), width, color="#5593c8", label="Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, df18_W.where(df18_W>0.5).count(), width, color="#74a7d2", label="Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, df18_W.where(df18_W>0.6).count(), width, color="#92badc", label="Signal (cut by 60%)")
for winter in bar1 + bar2 + bar3 + bar4:
    height = winter.get_height()
    plt.text(winter.get_x() + winter.get_width() / 2.0, height+100, f'{height:.0f}', ha='center', va='bottom', fontsize=6.5, color='black')

plt.grid(axis="y", linewidth=0.3)
plt.xticks(x, sig18_W.columns)
plt.ylabel('Stunden')
plt.xticks(rotation=90)
plt.legend(loc="center right", fontsize=7.5, bbox_to_anchor=(1.25, 0.5))
plt.gcf().set_size_inches(10, 4)
plt.suptitle('November - März (in 2018)', fontsize=14)
plt.savefig("Plots/web_freigabestunden_gruppiert_2018_winter.png", dpi=300, bbox_inches="tight")

# %%
x = np.arange(8)
width = 0.2
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('axes', labelsize=9)
bar1 = plt.bar(x, len(sig19_S)-(df19_S.where(df19_S>0.3).count()), width, color="dimgrey", label="Nicht-Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, len(sig19_S)-(df19_S.where(df19_S>0.4).count()), width, color="grey", label="Nicht-Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, len(sig19_S)-(df19_S.where(df19_S>0.5).count()), width, color="darkgrey", label="Nicht-Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, len(sig19_S)-(df19_S.where(df19_S>0.6).count()), width, color="lightgrey", label="Nicht-Signal (cut by 60%)")
for summer in bar1 + bar2 + bar3 + bar4:
    height = summer.get_height()
    plt.text(summer.get_x() + summer.get_width() / 2.0, height-100, f'{height:.0f}', ha='center', va='top', fontsize=6.5, color='black')

bar1 = plt.bar(x, df19_S.where(df19_S>0.3).count(), width, color="#3b7fb9", label="Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, df19_S.where(df19_S>0.4).count(), width, color="#5593c8", label="Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, df19_S.where(df19_S>0.5).count(), width, color="#74a7d2", label="Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, df19_S.where(df19_S>0.6).count(), width, color="#92badc", label="Signal (cut by 60%)")
for summer in bar1 + bar2 + bar3 + bar4:
    height = summer.get_height()
    plt.text(summer.get_x() + summer.get_width() / 2.0, height+100, f'{height:.0f}', ha='center', va='bottom', fontsize=6.5, color='black')

plt.grid(axis="y", linewidth=0.3)
plt.xticks(x, sig19_S.columns)
plt.ylabel('Stunden')
plt.xticks(rotation=90)
plt.legend(loc="center right", fontsize=7.5, bbox_to_anchor=(1.25, 0.5))
plt.gcf().set_size_inches(10, 4)
plt.suptitle('April - Oktober (in 2019)', fontsize=14)
plt.savefig("Plots/web_freigabestunden_gruppiert_2019_summer.png", dpi=300, bbox_inches="tight")
plt.show()

plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('axes', labelsize=9)
bar1 = plt.bar(x, len(sig19_W)-(df19_W.where(df19_W>0.3).count()), width, color="dimgrey", label="Nicht-Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, len(sig19_W)-(df19_W.where(df19_W>0.4).count()), width, color="grey", label="Nicht-Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, len(sig19_W)-(df19_W.where(df19_W>0.5).count()), width, color="darkgrey", label="Nicht-Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, len(sig19_W)-(df19_W.where(df19_W>0.6).count()), width, color="lightgrey", label="Nicht-Signal (cut by 60%)")
for winter in bar1 + bar2 + bar3 + bar4:
    height = winter.get_height()
    plt.text(winter.get_x() + winter.get_width() / 2.0, height-100, f'{height:.0f}', ha='center', va='top', fontsize=6.5, color='black')

bar1 = plt.bar(x, df19_W.where(df19_W>0.3).count(), width, color="#3b7fb9", label="Signal (cut by 30%)")
bar2 = plt.bar(x+0.2, df19_W.where(df19_W>0.4).count(), width, color="#5593c8", label="Signal (cut by 40%)")
bar3 = plt.bar(x+0.4, df19_W.where(df19_W>0.5).count(), width, color="#74a7d2", label="Signal (cut by 50%)")
bar4 = plt.bar(x+0.6, df19_W.where(df19_W>0.6).count(), width, color="#92badc", label="Signal (cut by 60%)")
for winter in bar1 + bar2 + bar3 + bar4:
    height = winter.get_height()
    plt.text(winter.get_x() + winter.get_width() / 2.0, height+100, f'{height:.0f}', ha='center', va='bottom', fontsize=6.5, color='black')

plt.grid(axis="y", linewidth=0.3)
plt.xticks(x, sig19_W.columns)
plt.ylabel('Stunden')
plt.xticks(rotation=90)
plt.legend(loc="center right", fontsize=7.5, bbox_to_anchor=(1.25, 0.5))
plt.gcf().set_size_inches(10, 4)
plt.suptitle('November - März (in 2019)', fontsize=14)
plt.savefig("Plots/web_freigabestunden_gruppiert_2019_winter.png", dpi=300, bbox_inches="tight")

# %%
df11_step = pd.DataFrame()
df11_not = pd.DataFrame()
df12_step = pd.DataFrame()
df12_not = pd.DataFrame()
df13_step = pd.DataFrame()
df13_not = pd.DataFrame()
df14_step = pd.DataFrame()
df14_not = pd.DataFrame()
df15_step = pd.DataFrame()
df15_not = pd.DataFrame()
df16_step = pd.DataFrame()
df16_not = pd.DataFrame()
df17_not = pd.DataFrame()
df17_step = pd.DataFrame()
df18_not = pd.DataFrame()
df18_step = pd.DataFrame()
df19_step = pd.DataFrame()
df19_not = pd.DataFrame()
df20_step = pd.DataFrame()
df20_not = pd.DataFrame()

#fig, ax = plt.subplots(1)
#fig, ax = plt.subplots(2)
for c in df11_sign.columns:
    df11_step[c] =  df11_sign[c].shift(1).ne(df11_sign[c]).where(df11_sign[c]==1).cumsum()
    df11_not[c] =  df11_sign[c].shift(1).ne(df11_sign[c]).where(df11_sign[c]==-1).cumsum()
for c in df12_sign.columns:
    df12_step[c] =  df12_sign[c].shift(1).ne(df12_sign[c]).where(df12_sign[c]==1).cumsum()
    df12_not[c] =  df12_sign[c].shift(1).ne(df12_sign[c]).where(df12_sign[c]==-1).cumsum()
for c in df13_sign.columns:
    df13_step[c] =  df13_sign[c].shift(1).ne(df13_sign[c]).where(df13_sign[c]==1).cumsum()
    df13_not[c] =  df13_sign[c].shift(1).ne(df13_sign[c]).where(df13_sign[c]==-1).cumsum()
for c in df14_sign.columns:
    df14_step[c] =  df14_sign[c].shift(1).ne(df14_sign[c]).where(df14_sign[c]==1).cumsum()
    df14_not[c] =  df14_sign[c].shift(1).ne(df14_sign[c]).where(df14_sign[c]==-1).cumsum()
for c in df15_sign.columns:
    df15_step[c] =  df15_sign[c].shift(1).ne(df15_sign[c]).where(df15_sign[c]==1).cumsum()
    df15_not[c] =  df15_sign[c].shift(1).ne(df15_sign[c]).where(df15_sign[c]==-1).cumsum()
for c in df16_sign.columns:
    df16_step[c] =  df16_sign[c].shift(1).ne(df16_sign[c]).where(df16_sign[c]==1).cumsum()
    df16_not[c] =  df16_sign[c].shift(1).ne(df16_sign[c]).where(df16_sign[c]==-1).cumsum()
for c in df17_sign.columns:
    df17_step[c] =  df17_sign[c].shift(1).ne(df17_sign[c]).where(df17_sign[c]==1).cumsum()
    df17_not[c] =  df17_sign[c].shift(1).ne(df17_sign[c]).where(df17_sign[c]==-1).cumsum()
for c in df18_sign.columns:
    df18_step[c] =  df18_sign[c].shift(1).ne(df18_sign[c]).where(df18_sign[c]==1).cumsum()
    df18_not[c] =  df18_sign[c].shift(1).ne(df18_sign[c]).where(df18_sign[c]==-1).cumsum()
for c in df19_sign.columns:
    df19_step[c] =  df19_sign[c].shift(1).ne(df19_sign[c]).where(df19_sign[c]==1).cumsum()
    df19_not[c] =  df19_sign[c].shift(1).ne(df19_sign[c]).where(df19_sign[c]==-1).cumsum()
for c in df20_sign.columns:
    df20_step[c] =  df20_sign[c].shift(1).ne(df20_sign[c]).where(df20_sign[c]==1).cumsum()
    df20_not[c] =  df20_sign[c].shift(1).ne(df20_sign[c]).where(df20_sign[c]==-1).cumsum()

# %%
df11_step.iloc[0,:] = 0
df12_step.iloc[0,:] = 0
df13_step.iloc[0,:] = 0
df14_step.iloc[0,:] = 0
df15_step.iloc[0,:] = 0
df16_step.iloc[0,:] = 0
df17_step.iloc[0,:] = 0
df18_step.iloc[0,:] = 0
df19_step.iloc[0,:] = 0
df20_step.iloc[0,:] = 0

df15_step
# Out:
#                     Neuhof I Neuhof III Maustrenk STERN I STERN II STERN III  \
# 2015-01-01 00:00:00        0          0         0       0        0         0
# 2015-01-01 01:00:00      NaN        NaN       NaN     NaN      NaN       NaN
# 2015-01-01 02:00:00      NaN        NaN       NaN     NaN      NaN       NaN
# 2015-01-01 03:00:00      NaN        NaN       NaN     NaN      NaN       NaN
# 2015-01-01 04:00:00      NaN        NaN       NaN     NaN      NaN       NaN
# ...                      ...        ...       ...     ...      ...       ...
# 2015-12-31 19:00:00      NaN      387.0     411.0     NaN      NaN       NaN
# 2015-12-31 20:00:00      NaN      387.0     411.0     NaN      NaN       NaN
# 2015-12-31 21:00:00      NaN        NaN     411.0     NaN      NaN       NaN
# 2015-12-31 22:00:00      NaN        NaN       NaN     NaN      NaN       NaN
# 2015-12-31 23:00:00      NaN        NaN       NaN     NaN      NaN       NaN
#
# ...

# %%
max(df16_step.max())
# Out:
# 391.0

# %%
max(df17_step.max())
# Out:
# 460.0

# %%
max_score = max(max(df13_step.max()), max(df14_step.max()), max(df15_step.max()),  max(df16_step.max()), max(df17_step.max()), max(df18_step.max()), max(df19_step.max()), max(df20_step.max()))

# %%
ax_scale = 0, (max_score + 20)
fig, ax = plt.subplots()
#plt.rc('font', size=6)
df14_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
ax.set_ylim(ax_scale)
fig.savefig("Plots/cumplot_2014_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df15_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2015_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df16_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2016_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df17_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2017_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df18_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2018_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df19_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2019_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots()
ax.set_ylim(ax_scale)
df20_step.plot(figsize=(10,5), cmap="plasma", ylabel="Number of Signal", grid=True, ax=ax)
fig.savefig("Plots/cumplot_2020_{}.png" .format(cut), dpi=300)

# %%
df11.fillna(0, inplace=True)
df12.fillna(0, inplace=True)
df13.fillna(0, inplace=True)
df14.fillna(0, inplace=True)
df15.fillna(0, inplace=True)
df16.fillna(0, inplace=True)
df17.fillna(0, inplace=True)
df18.fillna(0, inplace=True)
df19.fillna(0, inplace=True)
df20.fillna(0, inplace=True)
df11_sign.fillna(0, inplace=True)
df12_sign.fillna(0, inplace=True)
df13_sign.fillna(0, inplace=True)
df14_sign.fillna(0, inplace=True)
df15_sign.fillna(0, inplace=True)
df16_sign.fillna(0, inplace=True)
df17_sign.fillna(0, inplace=True)
df18_sign.fillna(0, inplace=True)
df19_sign.fillna(0, inplace=True)
df20_sign.fillna(0, inplace=True)

df11_step.fillna(0, inplace=True)
df11_not.fillna(0, inplace=True)
df12_step.fillna(0, inplace=True)
df12_not.fillna(0, inplace=True)
df13_step.fillna(0, inplace=True)
df13_not.fillna(0, inplace=True)
df14_step.fillna(0, inplace=True)
df14_not.fillna(0, inplace=True)
df15_step.fillna(0, inplace=True)
df15_not.fillna(0, inplace=True)
df16_step.fillna(0, inplace=True)
df16_not.fillna(0, inplace=True)
df17_step.fillna(0, inplace=True)
df17_not.fillna(0, inplace=True)
df18_step.fillna(0, inplace=True)
df18_not.fillna(0, inplace=True)
df19_step.fillna(0, inplace=True)
df19_not.fillna(0, inplace=True)
df20_step.fillna(0, inplace=True)
df20_not.fillna(0, inplace=True)

# %%
max(df14_sign["STERN III"])
# Out:
# -1

# %%
from matplotlib.dates import MonthLocator
from matplotlib.dates import DateFormatter

fig, ax = plt.subplots(len(df13_sign.columns), 1, sharex=True, sharey=True, figsize=(12,6))
for i, col in enumerate(df13_sign.columns):
        vis = pd.pivot_table(df13_sign, index=df13_sign.index.date, columns=df13_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=10, pad=-14)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2013 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2013_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df14_sign.columns):
        vis = pd.pivot_table(df14_sign, index=df14_sign.index.date, columns=df14_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2014 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2014_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df15_sign.columns):
        vis = pd.pivot_table(df15_sign, index=df15_sign.index.date, columns=df15_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2015 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2015_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df16_sign.columns):
        vis = pd.pivot_table(df16_sign, index=df16_sign.index.date, columns=df16_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2016 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2016_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df17_sign.columns):
        vis = pd.pivot_table(df17_sign, index=df17_sign.index.date, columns=df17_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2017 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2017_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df18_sign.columns):
        vis = pd.pivot_table(df18_sign, index=df18_sign.index.date, columns=df18_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2018 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2018_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df19_sign.columns):
        vis = pd.pivot_table(df19_sign, index=df19_sign.index.date, columns=df19_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2019 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2019_{}.png" .format(cut), dpi=300)
for i, col in enumerate(df20_sign.columns):
        vis = pd.pivot_table(df20_sign, index=df20_sign.index.date, columns=df20_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i])
        ax[i].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i].xaxis.set_major_locator(months)
        ax[i].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2020 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2020_{}.png" .format(cut), dpi=300)

# %%
fig, ax = plt.subplots(len(df18_sign.columns), 2, sharex=True, sharey=True, figsize=(12,6))
for i, col in enumerate(df18_sign.columns):
        vis = pd.pivot_table(df18_sign, index=df18_sign.index.date, columns=df18_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
for i, col in enumerate(df19_sign.columns):
        vis = pd.pivot_table(df19_sign, index=df19_sign.index.date, columns=df19_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 1])
        ax[i, 1].set_title(col, loc="right", color="lime", fontsize=12, pad=-11)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 1].xaxis.set_major_locator(months)
        ax[i, 1].xaxis.set_major_formatter(monthsFmt)
fig.suptitle('Heatmap Vergleich 2018-2019 (cut by {})' .format(cut), fontsize=14)
fig.savefig("Plots/heatmap_WEB_2018-2019_{}.png" .format(cut), dpi=300)

# %%
desc11 = pd.DataFrame()
desc11["Zeitraum mit Signal [h]"] = anzahl11[cut]
desc11["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl11[cut]
desc11["Anzahl Signal-Perioden"] = df11_step.max()
desc11["Durchschnittliche Dauer Signal [h]"] = (desc11["Zeitraum mit Signal [h]"]/desc11["Anzahl Signal-Perioden"])
desc11["Durchschnittliche Dauer Nicht-Signal [h]"] = desc11["Nicht-Signal-Zeitraum [h]"]/desc11["Anzahl Signal-Perioden"]

desc12 = pd.DataFrame()
desc12["Zeitraum mit Signal [h]"] = anzahl12[cut]
desc12["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl12[cut]
desc12["Anzahl Signal-Perioden"] = df12_step.max()
desc12["Durchschnittliche Dauer Signal [h]"] = (desc12["Zeitraum mit Signal [h]"]/desc12["Anzahl Signal-Perioden"])
desc12["Durchschnittliche Dauer Nicht-Signal [h]"] = desc12["Nicht-Signal-Zeitraum [h]"]/desc12["Anzahl Signal-Perioden"]

desc13 = pd.DataFrame()
desc13["Zeitraum mit Signal [h]"] = anzahl13[cut]
desc13["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl13[cut]
desc13["Anzahl Signal-Perioden"] = df13_step.max()
desc13["Durchschnittliche Dauer Signal [h]"] = (desc13["Zeitraum mit Signal [h]"]/desc13["Anzahl Signal-Perioden"])
desc13["Durchschnittliche Dauer Nicht-Signal [h]"] = desc13["Nicht-Signal-Zeitraum [h]"]/desc13["Anzahl Signal-Perioden"]

desc14 = pd.DataFrame()
desc14["Zeitraum mit Signal [h]"] = anzahl14[cut]
desc14["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl14[cut]
desc14["Anzahl Signal-Perioden"] = df14_step.max()
desc14["Durchschnittliche Dauer Signal [h]"] = (desc14["Zeitraum mit Signal [h]"]/desc14["Anzahl Signal-Perioden"])
desc14["Durchschnittliche Dauer Nicht-Signal [h]"] = desc14["Nicht-Signal-Zeitraum [h]"]/desc14["Anzahl Signal-Perioden"]

desc15 = pd.DataFrame()
desc15["Zeitraum mit Signal [h]"] = anzahl15[cut]
desc15["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl15[cut]
desc15["Anzahl Signal-Perioden"] = df15_step.max()
desc15["Durchschnittliche Dauer Signal [h]"] = (desc15["Zeitraum mit Signal [h]"]/desc15["Anzahl Signal-Perioden"])
desc15["Durchschnittliche Dauer Nicht-Signal [h]"] = desc15["Nicht-Signal-Zeitraum [h]"]/desc15["Anzahl Signal-Perioden"]

desc16 = pd.DataFrame()
desc16["Zeitraum mit Signal [h]"] = anzahl16[cut]
desc16["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl16[cut]
desc16["Anzahl Signal-Perioden"] = df16_step.max()
desc16["Durchschnittliche Dauer Signal [h]"] = (desc16["Zeitraum mit Signal [h]"]/desc16["Anzahl Signal-Perioden"])
desc16["Durchschnittliche Dauer Nicht-Signal [h]"] = desc16["Nicht-Signal-Zeitraum [h]"]/desc16["Anzahl Signal-Perioden"]

desc17 = pd.DataFrame()
desc17["Zeitraum mit Signal [h]"] = anzahl17[cut]
desc17["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl17[cut]
desc17["Anzahl Signal-Perioden"] = df17_step.max()
desc17["Durchschnittliche Dauer Signal [h]"] = (desc17["Zeitraum mit Signal [h]"]/desc17["Anzahl Signal-Perioden"])
desc17["Durchschnittliche Dauer Nicht-Signal [h]"] = desc17["Nicht-Signal-Zeitraum [h]"]/desc17["Anzahl Signal-Perioden"]

desc18 = pd.DataFrame()
desc18["Zeitraum mit Signal [h]"] = anzahl18[cut]
desc18["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl18[cut]
desc18["Anzahl Signal-Perioden"] = df18_step.max()
desc18["Durchschnittliche Dauer Signal [h]"] = (desc18["Zeitraum mit Signal [h]"]/desc18["Anzahl Signal-Perioden"])
desc18["Durchschnittliche Dauer Nicht-Signal [h]"] = desc18["Nicht-Signal-Zeitraum [h]"]/desc18["Anzahl Signal-Perioden"]

desc19 = pd.DataFrame()
desc19["Zeitraum mit Signal [h]"] = anzahl19[cut]
desc19["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl19[cut]
desc19["Anzahl Signal-Perioden"] = df19_step.max()
desc19["Durchschnittliche Dauer Signal [h]"] = (desc19["Zeitraum mit Signal [h]"]/desc19["Anzahl Signal-Perioden"])
desc19["Durchschnittliche Dauer Nicht-Signal [h]"] = desc19["Nicht-Signal-Zeitraum [h]"]/desc19["Anzahl Signal-Perioden"]

desc20 = pd.DataFrame()
desc20["Zeitraum mit Signal [h]"] = anzahl20[cut]
desc20["Nicht-Signal-Zeitraum [h]"] = 8760 - anzahl20[cut]
desc20["Anzahl Signal-Perioden"] = df20_step.max()
desc20["Durchschnittliche Dauer Signal [h]"] = (desc20["Zeitraum mit Signal [h]"]/desc20["Anzahl Signal-Perioden"])
desc20["Durchschnittliche Dauer Nicht-Signal [h]"] = desc20["Nicht-Signal-Zeitraum [h]"]/desc20["Anzahl Signal-Perioden"]

# %%
desc14
# Out:
#                         Zeitraum mit Signal [h]  Nicht-Signal-Zeitraum [h]  \
# Neuhof I                                   2064                       6696
# Neuhof III                                 1739                       7021
# Maustrenk                                  2777                       5983
# STERN I                                    1521                       7239
# STERN II                                   1543                       7217
# STERN III                                     0                       8760
# WEB 2015 Umgebung Wien                     1584                       7176
#
#                         Anzahl Signal-Perioden  \
# Neuhof I                                 302.0
# Neuhof III                               286.0
# Maustrenk                                347.0
# STERN I                                  294.0
# STERN II                                 289.0
# STERN III                                  0.0
# ...

# %%
fig, ax = plt.subplots(len(years), 3, sharex=True, figsize=(12,5))

for i in range(len(years)):
    ax[i, 0].set_ylabel("Stunden \n {}" .format(years[i]))
    ax[i, 1].set_ylabel("Anzahl \n Signal-Perioden")
    ax[i, 2].set_ylabel("Stunden \n {}" .format(years[i]))
desc11[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
desc11["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[0, 1])
desc11[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 2])

desc12[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[1, 0])
desc12["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[1, 1])
desc12[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[1, 2])

desc13[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[2, 0])
desc13["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[2, 1])
desc13[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[2, 2])

desc14[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[3, 0])
desc14["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[3, 1])
desc14[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[3, 2])

desc15[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[4, 0])
desc15["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[4, 1])
desc15[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[4, 2])

desc16[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[5, 0])
desc16["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[5, 1])
desc16[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[5, 2])

desc17[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[6, 0])
desc17["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[6, 1])
desc17[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[6, 2])

desc18[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[7, 0])
desc18["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[7, 1])
desc18[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[7, 2])

desc19[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[8, 0])
desc19["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[8, 1])
desc19[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[8, 2])

desc20[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[9, 0])
desc20["Anzahl Signal-Perioden"]\
   .plot(kind="bar",color=["cyan"], stacked=True, ax = ax[9, 1])
desc20[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[9, 2])

#fig.savefig("Plots/descriptive_WEB_all_{}.png" .format(cut), dpi=300, bbox_inches='tight')
# Out:
# <Axes: ylabel='Stunden \n 2020'>

# %%
dfToPlot14 = desc14.iloc[0]
dfToPlot14 = pd.DataFrame(dfToPlot14)
dfToPlot14 = dfToPlot14.transpose()
dfToPlot14
# Out:
#           Zeitraum mit Signal [h]  Nicht-Signal-Zeitraum [h]  \
# Neuhof I                   2064.0                     6696.0
#
#           Anzahl Signal-Perioden  Durchschnittliche Dauer Signal [h]  \
# Neuhof I                   302.0                            6.834437
#
#           Durchschnittliche Dauer Nicht-Signal [h]
# Neuhof I                                 22.172185

# %%
from matplotlib.dates import MonthLocator
from matplotlib.dates import DateFormatter
from matplotlib import gridspec

#gs_kw = (width_ratios=[4, 1])

fig, ax = plt.subplots(len(df14_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
#fig.tight_layout(w_pad=0.2)
plt.rc('font', size=12)
#plt.rc('axes', titlesize=8)     # fontsize of the axes title
#plt.rc('axes', labelsize=8)    # fontsize of the x and y labels
for i, col in enumerate(df14_sign.columns):
        vis = pd.pivot_table(df14_sign, index=df14_sign.index.date, columns=df14_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2014 (cut by {})' .format(cut), fontsize=16)
        dfToPlot14 = desc14.iloc[i]
        dfToPlot14 = pd.DataFrame(dfToPlot14)
        dfToPlot14 = dfToPlot14.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot14["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2014_with_signal_{}.png" .format(cut), dpi=300)

fig, ax = plt.subplots(len(df15_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
for i, col in enumerate(df15_sign.columns):
        vis = pd.pivot_table(df15_sign, index=df15_sign.index.date, columns=df15_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2015 (cut by {})' .format(cut), fontsize=16)
        dfToPlot15 = desc15.iloc[i]
        dfToPlot15 = pd.DataFrame(dfToPlot15)
        dfToPlot15 = dfToPlot15.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot15["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])

fig.savefig("Plots/heatmap_WEB_2015_with_signal_{}.png" .format(cut), dpi=300)

fig, ax = plt.subplots(len(df16_sign.columns), 2, gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
for i, col in enumerate(df16_sign.columns):
        vis = pd.pivot_table(df16_sign, index=df16_sign.index.date, columns=df16_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2016 (cut by {})' .format(cut), fontsize=16)
        dfToPlot16 = desc16.iloc[i]
        dfToPlot16 = pd.DataFrame(dfToPlot16)
        dfToPlot16 = dfToPlot16.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot16["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2016_with_signal_{}.png" .format(cut), dpi=300)

fig, ax = plt.subplots(len(df17_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
for i, col in enumerate(df17_sign.columns):
        vis = pd.pivot_table(df17_sign, index=df17_sign.index.date, columns=df17_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2017 (cut by {})' .format(cut), fontsize=16)
        dfToPlot17 = desc17.iloc[i]
        dfToPlot17 = pd.DataFrame(dfToPlot17)
        dfToPlot17 = dfToPlot17.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot17["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2017_with_signal_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots(len(df18_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
for i, col in enumerate(df18_sign.columns):
        vis = pd.pivot_table(df18_sign, index=df18_sign.index.date, columns=df18_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2018 (cut by {})' .format(cut), fontsize=16)
        dfToPlot18 = desc18.iloc[i]
        dfToPlot18 = pd.DataFrame(dfToPlot18)
        dfToPlot18 = dfToPlot18.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot18["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2018_with_signal_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots(len(df19_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(12,6))
for i, col in enumerate(df19_sign.columns):
        vis = pd.pivot_table(df19_sign, index=df19_sign.index.date, columns=df19_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2019 (cut by {})' .format(cut), fontsize=16)
        dfToPlot19 = desc19.iloc[i]
        dfToPlot19 = pd.DataFrame(dfToPlot19)
        dfToPlot19 = dfToPlot19.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot19["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2019_with_signal_{}.png" .format(cut), dpi=300)
fig, ax = plt.subplots(len(df20_sign.columns), 2,  gridspec_kw={"width_ratios":[9, 1]}, figsize=(8,5))
for i, col in enumerate(df20_sign.columns):
        vis = pd.pivot_table(df20_sign, index=df20_sign.index.date, columns=df20_sign.index.hour, values=col)
        sns.heatmap(vis.T, cbar=False, yticklabels=False, ax=ax[i, 0])
        ax[i, 0].set_title(col, loc="right", color="gold", fontsize=14, y=1, pad=-20)
        months = MonthLocator()
        monthsFmt = DateFormatter("%b")
        ax[i, 0].xaxis.set_major_locator(months)
        ax[i, 0].xaxis.set_major_formatter(monthsFmt)
        fig.suptitle('Heatmap 2020 (cut by {})' .format(cut), fontsize=16)
        dfToPlot20 = desc20.iloc[i]
        dfToPlot20 = pd.DataFrame(dfToPlot20)
        dfToPlot20 = dfToPlot20.transpose()
        ax[i, 1].set_xlabel=False
        ax[i, 1].pie([dfToPlot20["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
fig.savefig("Plots/heatmap_WEB_2020_with_signal_{}.png" .format(cut), dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Simon Schneider\Code\FLUCCOplus\notebooks\WEB_Netzdienlich - Edit.ipynb Cell 71 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Simon%20Schneider/Code/FLUCCOplus/notebooks/WEB_Netzdienlich%20-%20Edit.ipynb#Y130sZmlsZQ%3D%3D?line=22'>23</a>         dfToPlot14 = dfToPlot14.transpose()
#      <a href='vscode-notebook-cell:/c%3A/Users/Simon%20Schneider/Code/FLUCCOplus/notebooks/WEB_Netzdienlich%20-%20Edit.ipynb#Y130sZmlsZQ%3D%3D?line=23'>24</a>         ax[i, 1].set_xlabel=False
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Simon%20Schneider/Code/FLUCCOplus/notebooks/WEB_Netzdienlich%20-%20Edit.ipynb#Y130sZmlsZQ%3D%3D?line=24'>25</a>         ax[i, 1].pie([dfToPlot14["Zeitraum mit Signal [h]"], 8760], autopct='%1.1f%%',pctdistance = 1.5, radius = 1.3,startangle=0, colors = ["beige","black"])
# ...

# %%
desc14["Durchschnittliche Dauer Nicht-Signal [h]"]
# Out:
# Neuhof I                  22.172185
# Neuhof III                24.548951
# Maustrenk                 17.242075
# STERN I                   24.622449
# STERN II                  24.972318
# STERN III                       inf
# WEB 2015 Umgebung Wien    26.094545
# Name: Durchschnittliche Dauer Nicht-Signal [h], dtype: float64

# %%
max_score_2 = max(max(desc14["Durchschnittliche Dauer Nicht-Signal [h]"]),
                  max(desc15["Durchschnittliche Dauer Nicht-Signal [h]"]),
                  max(desc16["Durchschnittliche Dauer Nicht-Signal [h]"]),
                  max(desc17["Durchschnittliche Dauer Nicht-Signal [h]"]),
                  max(desc18["Durchschnittliche Dauer Nicht-Signal [h]"]),
                  max(desc19["Durchschnittliche Dauer Nicht-Signal [h]"]),
#                  max(desc20["Durchschnittliche Dauer Nicht-Signal [h]"])
                  )
max_score_2
# Out:
# inf

# %%
ax_scale_2 = 0, (max_score_2 + 10)

fig, ax = plt.subplots(6, 2, sharex=True, figsize=(14,5))
plt.rc('font', size=4.5)
#plt.rc('axes', linewidth=0.3)
#plt.rc('grid', linewidth=0.2)
for i in range(6):
    ax[i, 0].set_ylabel("Stunden \n {}" .format(years[i+3]))
    ax[i, 1].set_ylabel("Stunden \n {}" .format(years[i+3]))
    ax[i, 1].set_ylim(0,70)

#desc11[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar", color=["cyan", "black"], stacked=True, ax = ax[0, 0])
#desc11[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar", color=["orange", "grey"], stacked=False, ax = ax[0, 1])

#desc12[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[1, 0])
#desc12[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[1, 1])

#desc13[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[2, 0])
#desc13[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[2, 1])

desc14[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[0, 0])
desc14[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[0, 1])

desc15[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[1, 0])
desc15[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[1, 1])

desc16[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[2, 0])
desc16[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[2, 1])

desc17[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[3, 0])
desc17[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[3, 1])

desc18[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[4, 0])
desc18[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[4, 1])

desc19[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[5, 0])
desc19[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[5, 1])

#desc20[["Zeitraum mit Signal [h]","Nicht-Signal-Zeitraum [h]"]]\
#   .plot(kind="bar",color=["cyan", "black"], stacked=True, ax = ax[6, 0])
#desc20[["Durchschnittliche Dauer Signal [h]","Durchschnittliche Dauer Nicht-Signal [h]"]]\
#   .plot(kind="bar",color=["orange", "grey"], stacked=False, ax = ax[6, 1])
for i in range(6):
    for p in ax[i, 1].patches:
      ax[i, 1].annotate("{:.0f}" .format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=6, color='black', xytext=(0, -3),
                     textcoords='offset points')
for i in range(6):
    for p in ax[i, 0].patches:
      ax[i, 0].annotate("{:.1f}%" .format(p.get_height()*100/8760), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=7, color='black', xytext=(0, -5),
                     textcoords='offset points')

fig.savefig("Plots/descriptive_WEB_all_2.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# doku daziu:
# https://seaborn.pydata.org/generated/seaborn.histplot.html
