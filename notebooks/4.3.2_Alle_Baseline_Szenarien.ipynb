# %%
# %matplotlib inline
# %load_ext autoreload
import sys
sys.path.append("..\\")
sys.path

import matplotlib.pyplot as plt
from FLUCCOplus.notebooks import *

# %autoreload 2
# Out:
# FLUCCOplus.config  loaded!
# FLUCCOplus.notebooks loaded!

# %%
from FLUCCOplus.scenarios import *

df = pd.DataFrame()

scens = scenario_names_list[:]
for y in range(2015,2020):
    fig, ax = plt.subplots(len(scens),1,figsize=(12,12), sharey=True, sharex=True, layout="none")
    for i, name in enumerate(scens):
        scenario = Scenario(name, name, em_base=y)
        scenario.plot_heatmap(scenario.RES,ax=ax[i], vmin=-10, vmax=10)
        ax[i].set_title(scenario.name, pad=0)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# ...

# %%
scens = scenario_names_list[:]
scens = [scens[4], scens[8]]
scens
# Out:
# ['WEM 2030 (UBA17)', '100% Erneuerbare Deckung 2050 inkl Methan (FLUCCO+)']

# %%
#fig, ax = plt.subplots(len(scens),1,figsize=(12,12), sharey=True, sharex=True, layout="none")
for i, name in enumerate(scens):
    for y in [2015,2018,2019]:
        scenario = Scenario(name, name, em_base=y)
        ax = scenario.plot_heatmap(scenario.RES, vmin=-10, vmax=10)
        ax.set_title(f"ElMap {y} -> "+scenario.name, pad=0)
        ax.set_ylabel("Tagesverlauf")
        scenario.plot_signal()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\Simon Schneider\Code\FLUCCOplus\notebooks\..\FLUCCOplus\scenarios.py:306: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   props = sig_w.append(sig_s)
# c:\Users\Simon Schneider\Code\FLUCCOplus\notebooks\..\FLUCCOplus\scenarios.py:306: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   props = sig_w.append(sig_s)
# ...

# %%
df = pd.DataFrame()

scens = scenario_names_list[-3:]
for y in range(2015,2020):
    for i, name in enumerate(scens):
        scenario = Scenario(name, name, em_base=y)
        df.append(scenario.RES)


df.head()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\Simon Schneider\AppData\Local\Temp\ipykernel_23884\2277103241.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(scenario.RES)
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
# ...
