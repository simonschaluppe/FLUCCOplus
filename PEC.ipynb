# %%
import pandas as pd

df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="Tabelle3")

# %%
df.head()
# Out:
#        Szenario Sanierungsrate        Sanierung               Erneuerbare  \
# 0  Raus aus Gas     1,18% p.a.  Mindeststandard                     Keine
# 1  Raus aus Gas     1,18% p.a.  Mindeststandard          Dach-PV, Luft-WP
# 2  Raus aus Gas     1,18% p.a.  Mindeststandard  PV-Dach+Fass,Erd-WP,Flex
# 3  Raus aus Gas     1,18% p.a.         EnerPHit                     Keine
# 4  Raus aus Gas     1,18% p.a.         EnerPHit          Dach-PV, Luft-WP
#
#    Jahr  PE-Bilanz Alpha (mit Dichte-Ausgleich) $[kWh/m²NGF/a]$
# 0  2020                                         -63.009772
# 1  2020                                         -63.009772
# 2  2020                                         -63.009772
# 3  2020                                         -63.009772
# 4  2020                                         -63.009772

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("notebook")

# %%
y="PE-Bilanz Alpha (mit Dichte-Ausgleich) $[kWh/m²NGF/a]$"

sns.relplot(
    data=df, kind="line",
    x="Jahr", y=y,
    row ="Erneuerbare", col="Sanierung", hue="Szenario"
)

plt.show()

# %%
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="box")

# %%
df.head()
# Out:
#        Szenario Sanierungsrate        Sanierung               Erneuerbare  \
# 0  Raus aus Gas     1,18% p.a.  Mindeststandard                     Keine
# 1  Raus aus Gas     1,18% p.a.  Mindeststandard          Dach-PV, Luft-WP
# 2  Raus aus Gas     1,18% p.a.  Mindeststandard  PV-Dach+Fass,Erd-WP,Flex
# 3  Raus aus Gas     1,18% p.a.         EnerPHit                     Keine
# 4  Raus aus Gas     1,18% p.a.         EnerPHit          Dach-PV, Luft-WP
#
#    Jahr  PE-Bilanz Alpha (mit Dichte-Ausgleich) $[kWh/m²NGF/a]$  Unnamed: 6  \
# 0  2020                                         -63.009772              NaN
# 1  2020                                         -63.009772              NaN
# 2  2020                                         -63.009772              NaN
# 3  2020                                         -63.009772              NaN
# 4  2020                                         -63.009772              NaN
#
#   Unnamed: 7
# 0        NaN
# 1        NaN
# 2        NaN
# ...

# %%
sns.catplot(
    data=df,
    x="Jahr", y=y,
     hue="Szenario"
)
plt.legend(loc="upper left")
plt.show()

# %%
sns.catplot(
    data=df,
    x="Jahr", y=y,
    hue="Szenario",
    row ="Erneuerbare", col="Sanierung",
)
plt.legend(loc="upper left")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Jahr", y=y,
    hue="Szenario",
    linewidth=1
)
plt.legend(loc="upper left")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
y="PE-Bilanz Alpha (mit Dichte-Ausgleich) $[kWh/m²NGF/a]$"

sns.relplot(
    data=df[df.Szenario=="Raus aus Gas"], kind="line",
    x="Jahr", y=y,
    hue ="Erneuerbare", row="Sanierungsrate", col="Sanierung"
)
plt.ylim(-70,0)
plt.xlim(2020,2040)
plt.show()

# %%
sns.relplot(
    data=df[df.Szenario=="PV-Dach+Fassade (+RaG)"], kind="line",
    x="Jahr", y=y,
    hue ="Erneuerbare", row="Sanierungsrate", col="Sanierung"
)
plt.ylim(-70,0)
plt.xlim(2020,2040)
plt.show()

# %%
sns.relplot(
    data=df[df.Szenario=="PV-Dach+Fassade (+RaG)"], kind="line",
    x="Jahr", y=y,
    hue ="Erneuerbare", row="Sanierungsrate", col="Sanierung"
)
plt.ylim(-70,0)
plt.xlim(2020,2045)
plt.show()

# %%
sns.relplot(
    data=df[df.Szenario=="Anergienetz"], kind="line",
    x="Jahr", y=y,
    hue ="Erneuerbare", row="Sanierungsrate", col="Sanierung"
)
plt.ylim(-70,0)
plt.xlim(2020,2045)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27900\1203353724.py in <module>
# ----> 1 sns.relplot(
#       2     data=df[df.Szenario=="Anergienetz"], kind="line",
#       3     x="Jahr", y=y,
#       4     hue ="Erneuerbare", row="Sanierungsrate", col="Sanierung"
#       5 )
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
# ...

# %%
sns.catplot(
    data=df[df.Szenario=="Anergienetz"],
    x="Jahr", y=y,
    hue="Sanierungsrate"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27900\438853033.py in <module>
# ----> 1 sns.catplot(
#       2     data=df[df.Szenario=="Anergienetz"],
#       3     x="Jahr", y=y,
#       4     hue="Sanierungsrate"
#       5 )
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
# ...

# %%
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="neubau")

sns.catplot(
    data=df,
    x="Neubau", y=y,
    hue ="Erneuerbare",
    col="Sanierung"
)
plt.show()

# %%
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="Tabelle3")

sns.relplot(
    kind="line",
    data=df,
    x="Jahr", y=y,
    hue ="Erneuerbare",
    col="Sanierung"
)
plt.show()

# %%
plt.show()
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="box")

sns.boxplot(
    data=df[df.Szenario == "Anergienetz"],
    x="Jahr", y=y,
    hue="Erneuerbare",
    linewidth=1

)

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.show()
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="box")

sns.boxplot(
    data=df[df.Szenario == "Anergienetz"],
    x="Jahr", y=y,
    hue="Sanierungsrate",
    linewidth=1

)

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.read_excel("C:/Users/Simon Schneider/Desktop/pecq/simple.xlsx", sheet_name="box")

sns.boxplot(
    data=df[df.Szenario=="Anergienetz"],
    x="Jahr", y=y,
    hue ="Sanierung",
    linewidth=1


)

plt.xticks(rotation=45, ha='right')
plt.show()
